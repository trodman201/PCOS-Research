# %%
import pandas as pd

# %%
df = pd.read_excel('PCOS_data_without_infertility.xlsx', sheet_name='Full_new')
df
# Out:
#      Sl. No  Patient File No.  PCOS (Y/N)   Age (yrs)  Weight (Kg)  \
# 0         1                 1           0          28         44.6
# 1         2                 2           0          36         65.0
# 2         3                 3           1          33         68.8
# 3         4                 4           0          37         65.0
# 4         5                 5           0          25         52.0
# ..      ...               ...         ...         ...          ...
# 536     537               537           0          35         50.0
# 537     538               538           0          30         63.2
# 538     539               539           0          36         54.0
# 539     540               540           0          27         50.0
# 540     541               541           1          23         82.0
#
#      Height(Cm)         BMI  Blood Group  Pulse rate(bpm)   RR (breaths/min)  \
# 0        152.000  19.304017           15                78                22
# ...

# %%
new_df = df[['PCOS (Y/N)','Weight (Kg)', 'BMI','FSH/LH', 'FSH(mIU/mL)', 'LH(mIU/mL)']]
new_df
# Out:
#      PCOS (Y/N)  Weight (Kg)        BMI    FSH/LH  FSH(mIU/mL)  LH(mIU/mL)
# 0             0         44.6  19.304017  2.160326         7.95        3.68
# 1             0         65.0  24.921163  6.174312         6.73        1.09
# 2             1         68.8  25.270891  6.295455         5.54        0.88
# 3             0         65.0  29.674945  3.415254         8.06        2.36
# 4             0         52.0  20.060954  4.422222         3.98        0.90
# ..          ...          ...        ...       ...          ...         ...
# 536           0         50.0  18.456637  5.558011        10.06        1.81
# 537           0         63.2  25.316456  1.785211         5.07        2.84
# 538           0         54.0  23.372576  4.302158        11.96        2.78
# 539           0         50.0  22.222222  1.016166         4.40        4.33
# 540           1         82.0  30.119376  0.927907         3.99        4.30
#
# [541 rows x 6 columns]

# %%
pcos = new_df[new_df['PCOS (Y/N)'].isin([1])]
pcos
# Out:
#      PCOS (Y/N)  Weight (Kg)        BMI    FSH/LH  FSH(mIU/mL)  LH(mIU/mL)
# 2             1         68.8  25.270891  6.295455         5.54        0.88
# 12            1         74.0  32.029086  1.324503         2.00        1.51
# 19            1         85.0  31.221304  2.333333         1.89        0.81
# 24            1         63.0  25.236340  6.000000         5.34        0.89
# 26            1         76.0  29.687500  2.223022         6.18        2.78
# ..          ...          ...        ...       ...          ...         ...
# 520           1         50.0  17.715420  2.111111         4.56        2.16
# 523           1         60.0  26.666667  5.710000         5.71        1.00
# 524           1         70.0  24.026586  2.107843         4.30        2.04
# 533           1         53.5  20.500862  0.796137         3.71        4.66
# 540           1         82.0  30.119376  0.927907         3.99        4.30
#
# [177 rows x 6 columns]

# %%
no_pcos = new_df[new_df['PCOS (Y/N)'].isin([0])]

# %%
p1 = new_df[new_df['PCOS (Y/N)'].isin([1])]
p1 = p1[p1['BMI'] <= 19]
p1
# Out:
#      PCOS (Y/N)  Weight (Kg)        BMI     FSH/LH  FSH(mIU/mL)  LH(mIU/mL)
# 76            1         43.0  18.611496   2.407767         4.96        2.06
# 123           1         40.0  17.777778   0.970874         5.00        5.15
# 221           1         31.0  12.417882   0.601810         3.99        6.63
# 237           1         42.0  17.709563   2.129450         6.58        3.09
# 293           1         36.0  15.378700   0.831703         4.25        5.11
# 306           1         40.0  16.649324   4.433735         3.68        0.83
# 342           1         40.0  16.023073   2.074074         6.72        3.24
# 392           1         45.0  18.025957   1.758958         5.40        3.07
# 451           1         44.0  16.860522  17.934783         8.25        0.46
# 457           1         38.0  15.126797   0.601810         3.99        6.63
# 520           1         50.0  17.715420   2.111111         4.56        2.16

# %%
p2 = new_df[new_df['PCOS (Y/N)'].isin([1])]
p2 = p2[(p2['BMI'] >= 19) & (p2['BMI'] <= 25)]
p2
# Out:
#      PCOS (Y/N)  Weight (Kg)        BMI     FSH/LH  FSH(mIU/mL)  LH(mIU/mL)
# 29            1         56.0  24.238227   2.025210         2.41        1.19
# 44            1         59.0  23.634033   4.126582         3.26        0.79
# 49            1         51.0  21.504470   0.941667         2.26        2.40
# 50            1         68.0  22.985398   0.806569         4.42        5.48
# 52            1         50.0  20.284799   1.731051         7.08        4.09
# ..          ...          ...        ...        ...          ...         ...
# 486           1         49.1  19.421700   1.134529         7.59        6.69
# 493           1         50.0  21.082813  29.730769         7.73        0.26
# 509           1         54.0  23.372576   7.702703         2.85        0.37
# 524           1         70.0  24.026586   2.107843         4.30        2.04
# 533           1         53.5  20.500862   0.796137         3.71        4.66
#
# [73 rows x 6 columns]

# %%
p3 = new_df[new_df['PCOS (Y/N)'].isin([1])]
# Drop rows where 'BMI' is less than 25
p3 = p3[(p3['BMI'] >= 25)]
p3
p3.dropna()
# Out:
#      PCOS (Y/N)  Weight (Kg)        BMI    FSH/LH  FSH(mIU/mL)  LH(mIU/mL)
# 2             1         68.8  25.270891  6.295455         5.54        0.88
# 12            1         74.0  32.029086  1.324503         2.00        1.51
# 19            1         85.0  31.221304  2.333333         1.89        0.81
# 24            1         63.0  25.236340  6.000000         5.34        0.89
# 26            1         76.0  29.687500  2.223022         6.18        2.78
# ..          ...          ...        ...       ...          ...         ...
# 489           1         63.0  30.808352  3.029915         7.09        2.34
# 495           1         64.0  26.638918  4.449612         5.74        1.29
# 512           1         72.0  26.446281  3.736842         2.13        0.57
# 523           1         60.0  26.666667  5.710000         5.71        1.00
# 540           1         82.0  30.119376  0.927907         3.99        4.30
#
# [94 rows x 6 columns]

# %%
#underweight no pcos
n1 = new_df[new_df['PCOS (Y/N)'].isin([0])]
n1 = n1[n1['BMI'] <= 19]

# %%
n2 = new_df[new_df['PCOS (Y/N)'].isin([0])]
n2 = n2[(n2['BMI'] >= 19) & (n2['BMI'] <= 25)]
n2
# Out:
#      PCOS (Y/N)  Weight (Kg)        BMI    FSH/LH  FSH(mIU/mL)  LH(mIU/mL)
# 0             0         44.6  19.304017  2.160326         7.95        3.68
# 1             0         65.0  24.921163  6.174312         6.73        1.09
# 4             0         52.0  20.060954  4.422222         3.98        0.90
# 7             0         58.5  23.139907  1.583062         4.86        3.07
# 9             0         52.0  23.111111  1.854305         2.80        1.51
# ..          ...          ...        ...       ...          ...         ...
# 530           0         61.0  24.435187  3.657480         9.29        2.54
# 532           0         56.0  22.292122  2.017647        10.29        5.10
# 534           0         48.0  19.107533  0.398721         3.74        9.38
# 538           0         54.0  23.372576  4.302158        11.96        2.78
# 539           0         50.0  22.222222  1.016166         4.40        4.33
#
# [203 rows x 6 columns]

# %%
n3 = new_df[new_df['PCOS (Y/N)'].isin([0])]
# Drop rows where 'BMI' is less than 25
n3 = n3[(n3['BMI'] >= 25)]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x="PCOS (Y/N)", y="BMI", data=p1)
sns.boxplot(x="PCOS (Y/N)", y="BMI", data=n1)
plt.title('Underweight Groups')
# Out:
# Text(0.5, 1.0, 'Underweight Groups')

# %%
sns.boxplot(x="PCOS (Y/N)", y="BMI", data=p2)
sns.boxplot(x="PCOS (Y/N)", y="BMI", data=n2)
plt.title('Healthy weight Groups')
# Out:
# Text(0.5, 1.0, 'Healthy weight Groups')

# %%
sns.boxplot(x="PCOS (Y/N)", y="BMI", data=p3)
sns.boxplot(x="PCOS (Y/N)", y="BMI", data=n3)
plt.title('Overweight Groups')
# Out:
# Text(0.5, 1.0, 'Overweight Groups')

# %%
sns.boxplot(x="PCOS (Y/N)", y="BMI", data=pcos)
sns.boxplot(x="PCOS (Y/N)", y="BMI", data=no_pcos)
plt.title('PCOS VS No PCOS by BMI')
# Out:
# Text(0.5, 1.0, 'PCOS VS No PCOS by BMI')

# %%
sns.boxplot(x="PCOS (Y/N)", y="FSH/LH", data=p1)
plt.title('Underweight PCOS Group and their FSH/LH')
# Out:
# Text(0.5, 1.0, 'Underweight PCOS Group and their FSH/LH')

# %%
sns.boxplot(x="PCOS (Y/N)", y="FSH/LH", data=p2)
plt.title('Normal Weight PCOS Group and their FSH/LH')
# Out:
# Text(0.5, 1.0, 'Normal Weight PCOS Group and their FSH/LH')

# %%
print("Unique values in 'FSH/LH' column of p3 before filtering:")
print(p3['FSH/LH'].unique())
values_to_drop = [327, 61.875, 21.33333333]
filtered_p3 = p3[~p3['FSH/LH'].isin(values_to_drop)]
print("Unique values in 'FSH/LH' column of p3 after filtering:")
print(filtered_p3['FSH/LH'].unique())
# Out:
# Unique values in 'FSH/LH' column of p3 before filtering:
# [  6.29545455   1.32450331   2.33333333   6.           2.22302158
#    0.77314815  21.51851852   9.73333333   1.91769547   1.76923077
#    4.15810277   2.35416667   1.32482599   1.01970443   0.83561644
#    0.5959596    1.11418685   0.95251397   1.95718654   7.275
#    1.36203523   0.80363636   5.07761194   1.02040816   7.11363636
#    0.85034014   1.62454874   2.86335404  61.875        1.61290323
#    3.55882353   6.48967552   4.17721519   2.65         7.45238095
#    0.4352518    9.58823529   1.76296296   2.83428571   2.09615385
#    2.83673469   3.18         2.83185841   1.64171123   0.69044586
#  327.           7.52         1.125        1.06224066   2.5
#    1.84738956   1.3559322    2.67073171   1.78723404   5.6407767
#    0.48174157   2.45323741   3.1981982    0.70923379   1.47835498
#    0.90240811   1.81518152  21.33333333   1.38034188   0.89719626
#    2.18681319   5.59322034   2.325        0.86046512   5.58181818
# ...

# %%
sns.boxplot(x="PCOS (Y/N)", y="FSH/LH", data=filtered_p3)
plt.title('Overweight PCOS Group and their FSH Levels')
# Out:
# Text(0.5, 1.0, 'Overweight PCOS Group and their FSH Levels')

# %%
sns.boxplot(x="PCOS (Y/N)", y="FSH/LH", data=n1)
plt.title('Underweight non-PCOS Group and their FSH/LH')
# Out:
# Text(0.5, 1.0, 'Underweight non-PCOS Group and their FSH/LH')

# %%
threshold_FSH_LH = 20
threshold_FSH = 20

filtered_n2 = n2[(n2['FSH/LH'] <= threshold_FSH_LH) &
                 (n2['FSH(mIU/mL)'] <= threshold_FSH)]

print(filtered_n2)
# Out:
#      PCOS (Y/N)  Weight (Kg)        BMI    FSH/LH  FSH(mIU/mL)  LH(mIU/mL)
# 0             0         44.6  19.304017  2.160326         7.95        3.68
# 1             0         65.0  24.921163  6.174312         6.73        1.09
# 4             0         52.0  20.060954  4.422222         3.98        0.90
# 7             0         58.5  23.139907  1.583062         4.86        3.07
# 9             0         52.0  23.111111  1.854305         2.80        1.51
# ..          ...          ...        ...       ...          ...         ...
# 530           0         61.0  24.435187  3.657480         9.29        2.54
# 532           0         56.0  22.292122  2.017647        10.29        5.10
# 534           0         48.0  19.107533  0.398721         3.74        9.38
# 538           0         54.0  23.372576  4.302158        11.96        2.78
# 539           0         50.0  22.222222  1.016166         4.40        4.33
#
# [197 rows x 6 columns]

# %%
sns.boxplot(x="PCOS (Y/N)", y="FSH/LH", data=filtered_n2)

plt.title('Normal non-PCOS Group and their FSH/LH')
plt.show()

# %%
sns.boxplot(x="PCOS (Y/N)", y="FSH/LH", data=n3)
plt.title('Overweight  non-PCOS Group and their FSH/LH')
# Out:
# Text(0.5, 1.0, 'Overweight  non-PCOS Group and their FSH/LH')

# %%
sns.boxplot(x="PCOS (Y/N)", y="FSH(mIU/mL)", data=p1)
plt.title('Underweight PCOS Group and their FSH Level')
# Out:
# Text(0.5, 1.0, 'Underweight PCOS Group and their FSH Level')

# %%
sns.boxplot(x="PCOS (Y/N)", y="FSH(mIU/mL)", data=p2)
plt.title('Normal Weight PCOS Group and their FSH Level')
# Out:
# Text(0.5, 1.0, 'Normal Weight PCOS Group and their FSH Level')

# %%
sns.boxplot(x="PCOS (Y/N)", y="FSH(mIU/mL)", data=filtered_p3)
plt.title('Overweight PCOS Group and their FSH Level')
# Out:
# Text(0.5, 1.0, 'Overweight PCOS Group and their FSH Level')

# %%
sns.boxplot(x="PCOS (Y/N)", y="FSH(mIU/mL)", data=n1)
plt.title('Underweight non-PCOS Group and their FSH Level')
# Out:
# Text(0.5, 1.0, 'Underweight non-PCOS Group and their FSH Level')

# %%
sns.boxplot(x="PCOS (Y/N)", y="FSH(mIU/mL)", data=filtered_n2)
plt.title('Normal Weight non-PCOS Group and their FSH Level')
# Out:
# Text(0.5, 1.0, 'Normal Weight non-PCOS Group and their FSH Level')

# %%
sns.boxplot(x="PCOS (Y/N)", y="FSH(mIU/mL)", data=n3)
plt.title('Overweight non-PCOS Group and their FSH Level')
# Out:
# Text(0.5, 1.0, 'Overweight non-PCOS Group and their FSH Level')

# %%
sns.boxplot(x="PCOS (Y/N)", y="LH(mIU/mL)", data=n1)
plt.title('Underweight non-PCOS Group and their LH Level')
# Out:
# Text(0.5, 1.0, 'Underweight non-PCOS Group and their LH Level')

# %%
sns.boxplot(x="PCOS (Y/N)", y="LH(mIU/mL)", data=filtered_n2)
plt.title('Normal Weight non-PCOS Group and their LH Level')
# Out:
# Text(0.5, 1.0, 'Normal Weight non-PCOS Group and their LH Level')

# %%
sns.boxplot(x="PCOS (Y/N)", y="LH(mIU/mL)", data=n3)
plt.title('Overweight non-PCOS Group and their LH Level')
# Out:
# Text(0.5, 1.0, 'Overweight non-PCOS Group and their LH Level')

# %%
sns.boxplot(x="PCOS (Y/N)", y="LH(mIU/mL)", data=p1)
plt.title('Underweight PCOS Group and their LH Level')
# Out:
# Text(0.5, 1.0, 'Underweight PCOS Group and their LH Level')

# %%
p2_filtered = p2[p2['LH(mIU/mL)'] <= 20]
sns.boxplot(x="PCOS (Y/N)", y="LH(mIU/mL)", data=p2_filtered)
plt.title('Normal Weight PCOS Group and their LH Level')
# Out:
# Text(0.5, 1.0, 'Normal Weight PCOS Group and their LH Level')

# %%
sns.boxplot(x="PCOS (Y/N)", y="LH(mIU/mL)", data=filtered_p3)
plt.title('Overweight PCOS Group and their LH Level')
# Out:
# Text(0.5, 1.0, 'Overweight PCOS Group and their LH Level')

# %%
import numpy as np
from scipy.stats import median_test

# %%
pcos = pd.DataFrame({'BMI': np.random.normal(loc=10, scale=2, size=50)})
no_pcos = pd.DataFrame({'BMI': np.random.normal(loc=12, scale=2, size=50)})

# Extract the values column from each DataFrame
group1 = pcos['BMI'].to_numpy()
group2 = no_pcos['BMI'].to_numpy()

statistic, p_value, medians, table = median_test(group1, group2)

print("Mood's median test statistic:", statistic)
print("P-value:", p_value)
print("Medians:", medians)
print("Contingency table:")
print(table)
# Out:
# Mood's median test statistic: 0.36
# P-value: 0.5485062355001471
# Medians: 10.887187941687747
# Contingency table:
# [[23 27]
#  [27 23]]

# %%
n1 = pd.DataFrame({'FSH/LH': np.random.normal(loc=10, scale=2, size=50)})
n2 = pd.DataFrame({'FSH/LH': np.random.normal(loc=12, scale=2, size=50)})
n3 = pd.DataFrame({'FSH/LH': np.random.normal(loc=15, scale=3, size=50)})

# Extract the values column from each DataFrame
group1 = n1['FSH/LH'].to_numpy()
group2 = n2['FSH/LH'].to_numpy()
group3 = n3['FSH/LH'].to_numpy()

statistic, p_value, medians, table = median_test(group1, group2, group3)

print("Mood's median test statistic:", statistic)
print("P-value:", p_value)
print("Medians:", medians)
print("Contingency table:")
print(table)
# Out:
# Mood's median test statistic: 61.92
# P-value: 3.5829672644062e-14
# Medians: 12.095079440131624
# Contingency table:
# [[ 4 28 43]
#  [46 22  7]]

# %%
p1 = pd.DataFrame({'FSH/LH': np.random.normal(loc=10, scale=2, size=50)})
p2 = pd.DataFrame({'FSH/LH': np.random.normal(loc=12, scale=2, size=50)})
p3 = pd.DataFrame({'FSH/LH': np.random.normal(loc=15, scale=3, size=50)})

# Extract the values column from each DataFrame
group1 = p1['FSH/LH'].to_numpy()
group2 = p2['FSH/LH'].to_numpy()
group3 = p3['FSH/LH'].to_numpy()

statistic, p_value, medians, table = median_test(group1, group2, group3)

print("Mood's median test statistic:", statistic)
print("P-value:", p_value)
print("Medians:", medians)
print("Contingency table:")
print(table)
# Out:
# Mood's median test statistic: 36.0
# P-value: 1.522997974471264e-08
# Medians: 12.098202612756527
# Contingency table:
# [[10 25 40]
#  [40 25 10]]
